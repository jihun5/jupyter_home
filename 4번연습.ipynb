# %%
import requests
import json
import datetime as dt
from pandas import DataFrame

# %%
urlFmt = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key={key}&targetDt={targetDt}"

# %%
API_KEY = "6d2cf4aa96725383235c717f2e569f1e"

# %%
date = dt.datetime.now() - dt.timedelta(days=1)
yesterday = date.strftime("%Y%m%d")
yesterday
# Out:
# '20230617'

# %%
url = urlFmt.format(key=API_KEY, targetDt=yesterday)
url
# Out:
# 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=6d2cf4aa96725383235c717f2e569f1e&targetDt=20230617'

# %%
session = requests.Session()
session.headers.update({
    "Referer": "",
    "User-Agent" : "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36"

})

# %%
r = session.get(url)
if r.status_code != 200:
    msg = "[%d Error] %s 에러가 발생함" % (r.status_code, r.reason)
    raise Exception(msg)

# %%
r.encoding = "utf-8"
data = json.loads(r.text)
data
# Out:
# {'boxOfficeResult': {'boxofficeType': '일별 박스오피스',
#   'showRange': '20230617~20230617',
#   'dailyBoxOfficeList': [{'rnum': '1',
#     'rank': '1',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20226411',
#     'movieNm': '범죄도시3',
#     'openDt': '2023-05-31',
#     'salesAmt': '2850445922',
#     'salesShare': '41.9',
#     'salesInten': '1453653836',
#     'salesChange': '104.1',
#     'salesAcc': '85956973037',
#     'audiCnt': '278729',
#     'audiInten': '139733',
#     'audiChange': '100.5',
#     'audiAcc': '8680598',
#     'scrnCnt': '1464',
#     'showCnt': '7378'},
#    {'rnum': '2',
#     'rank': '2',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20228930',
#     'movieNm': '엘리멘탈',
#     'openDt': '2023-06-14',
#     'salesAmt': '1793175846',
#     'salesShare': '26.4',
#     'salesInten': '1140734210',
#     'salesChange': '174.8',
#     'salesAcc': '3336652509',
#     'audiCnt': '177851',
#     'audiInten': '112850',
#     'audiChange': '173.6',
#     'audiAcc': '336812',
#     'scrnCnt': '1221',
#     'showCnt': '4477'},
#    {'rnum': '3',
#     'rank': '3',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20231971',
#     'movieNm': '플래시',
#     'openDt': '2023-06-14',
#     'salesAmt': '1412437187',
#     'salesShare': '20.8',
#     'salesInten': '751869631',
#     'salesChange': '113.8',
#     'salesAcc': '3474133965',
#     'audiCnt': '130312',
#     'audiInten': '69719',
#     'audiChange': '115.1',
#     'audiAcc': '324602',
#     'scrnCnt': '1239',
#     'showCnt': '4645'},
#    {'rnum': '4',
#     'rank': '4',
#     'rankInten': '0',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20232025',
#     'movieNm': '트랜스포머: 비스트의 서막',
#     'openDt': '2023-06-06',
#     'salesAmt': '326281508',
#     'salesShare': '4.8',
#     'salesInten': '167091544',
#     'salesChange': '105',
#     'salesAcc': '6999262769',
#     'audiCnt': '32662',
#     'audiInten': '16468',
#     'audiChange': '101.7',
#     'audiAcc': '689264',
#     'scrnCnt': '626',
#     'showCnt': '1259'},
#    {'rnum': '5',
#     'rank': '5',
#     'rankInten': '1',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20231496',
#     'movieNm': '가디언즈 오브 갤럭시: Volume 3',
#     'openDt': '2023-05-03',
#     'salesAmt': '74488561',
#     'salesShare': '1.1',
#     'salesInten': '36960326',
#     'salesChange': '98.5',
#     'salesAcc': '44089148518',
#     'audiCnt': '7042',
#     'audiInten': '3413',
#     'audiChange': '94',
#     'audiAcc': '4183204',
#     'scrnCnt': '202',
#     'showCnt': '253'},
#    {'rnum': '6',
#     'rank': '6',
#     'rankInten': '7',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20090860',
#     'movieNm': '포켓 몬스터 DP: 아르세우스 초극의 시공으로',
#     'openDt': '2009-12-24',
#     'salesAmt': '62235941',
#     'salesShare': '0.9',
#     'salesInten': '55283563',
#     'salesChange': '795.2',
#     'salesAcc': '4349844994',
#     'audiCnt': '6475',
#     'audiInten': '5720',
#     'audiChange': '757.6',
#     'audiAcc': '566226',
#     'scrnCnt': '326',
#     'showCnt': '388'},
#    {'rnum': '7',
#     'rank': '7',
#     'rankInten': '-2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20211937',
#     'movieNm': '귀공자',
#     'openDt': '2023-06-21',
#     'salesAmt': '42776700',
#     'salesShare': '0.6',
#     'salesInten': '7136700',
#     'salesChange': '20',
#     'salesAcc': '163858700',
#     'audiCnt': '3546',
#     'audiInten': '-3582',
#     'audiChange': '-50.3',
#     'audiAcc': '26612',
#     'scrnCnt': '16',
#     'showCnt': '16'},
#    {'rnum': '8',
#     'rank': '8',
#     'rankInten': '3',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20231839',
#     'movieNm': '인어공주',
#     'openDt': '2023-05-24',
#     'salesAmt': '27035851',
#     'salesShare': '0.4',
#     'salesInten': '17228264',
#     'salesChange': '175.7',
#     'salesAcc': '6593279017',
#     'audiCnt': '2576',
#     'audiInten': '1622',
#     'audiChange': '170',
#     'audiAcc': '640283',
#     'scrnCnt': '103',
#     'showCnt': '123'},
#    {'rnum': '9',
#     'rank': '9',
#     'rankInten': '-2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20231677',
#     'movieNm': '남은 인생 10년',
#     'openDt': '2023-05-24',
#     'salesAmt': '21712100',
#     'salesShare': '0.3',
#     'salesInten': '6766500',
#     'salesChange': '45.3',
#     'salesAcc': '1324148100',
#     'audiCnt': '2039',
#     'audiInten': '527',
#     'audiChange': '34.9',
#     'audiAcc': '123350',
#     'scrnCnt': '57',
#     'showCnt': '103'},
#    {'rnum': '10',
#     'rank': '10',
#     'rankInten': '2',
#     'rankOldAndNew': 'OLD',
#     'movieCd': '20231592',
#     'movieNm': '분노의 질주: 라이드 오어 다이',
#     'openDt': '2023-05-17',
#     'salesAmt': '14698775',
#     'salesShare': '0.2',
#     'salesInten': '6243513',
#     'salesChange': '73.8',
#     'salesAcc': '18429259665',
#     'audiCnt': '1424',
#     'audiInten': '563',
#     'audiChange': '65.4',
#     'audiAcc': '1768880',
#     'scrnCnt': '67',
#     'showCnt': '76'}]}}

# %%
dailyBoxOfficeList = data['boxOfficeResult']['dailyBoxOfficeList']
dailyBoxOfficeList
# Out:
# [{'rnum': '1',
#   'rank': '1',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20226411',
#   'movieNm': '범죄도시3',
#   'openDt': '2023-05-31',
#   'salesAmt': '2850445922',
#   'salesShare': '41.9',
#   'salesInten': '1453653836',
#   'salesChange': '104.1',
#   'salesAcc': '85956973037',
#   'audiCnt': '278729',
#   'audiInten': '139733',
#   'audiChange': '100.5',
#   'audiAcc': '8680598',
#   'scrnCnt': '1464',
#   'showCnt': '7378'},
#  {'rnum': '2',
#   'rank': '2',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20228930',
#   'movieNm': '엘리멘탈',
#   'openDt': '2023-06-14',
#   'salesAmt': '1793175846',
#   'salesShare': '26.4',
#   'salesInten': '1140734210',
#   'salesChange': '174.8',
#   'salesAcc': '3336652509',
#   'audiCnt': '177851',
#   'audiInten': '112850',
#   'audiChange': '173.6',
#   'audiAcc': '336812',
#   'scrnCnt': '1221',
#   'showCnt': '4477'},
#  {'rnum': '3',
#   'rank': '3',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231971',
#   'movieNm': '플래시',
#   'openDt': '2023-06-14',
#   'salesAmt': '1412437187',
#   'salesShare': '20.8',
#   'salesInten': '751869631',
#   'salesChange': '113.8',
#   'salesAcc': '3474133965',
#   'audiCnt': '130312',
#   'audiInten': '69719',
#   'audiChange': '115.1',
#   'audiAcc': '324602',
#   'scrnCnt': '1239',
#   'showCnt': '4645'},
#  {'rnum': '4',
#   'rank': '4',
#   'rankInten': '0',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20232025',
#   'movieNm': '트랜스포머: 비스트의 서막',
#   'openDt': '2023-06-06',
#   'salesAmt': '326281508',
#   'salesShare': '4.8',
#   'salesInten': '167091544',
#   'salesChange': '105',
#   'salesAcc': '6999262769',
#   'audiCnt': '32662',
#   'audiInten': '16468',
#   'audiChange': '101.7',
#   'audiAcc': '689264',
#   'scrnCnt': '626',
#   'showCnt': '1259'},
#  {'rnum': '5',
#   'rank': '5',
#   'rankInten': '1',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231496',
#   'movieNm': '가디언즈 오브 갤럭시: Volume 3',
#   'openDt': '2023-05-03',
#   'salesAmt': '74488561',
#   'salesShare': '1.1',
#   'salesInten': '36960326',
#   'salesChange': '98.5',
#   'salesAcc': '44089148518',
#   'audiCnt': '7042',
#   'audiInten': '3413',
#   'audiChange': '94',
#   'audiAcc': '4183204',
#   'scrnCnt': '202',
#   'showCnt': '253'},
#  {'rnum': '6',
#   'rank': '6',
#   'rankInten': '7',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20090860',
#   'movieNm': '포켓 몬스터 DP: 아르세우스 초극의 시공으로',
#   'openDt': '2009-12-24',
#   'salesAmt': '62235941',
#   'salesShare': '0.9',
#   'salesInten': '55283563',
#   'salesChange': '795.2',
#   'salesAcc': '4349844994',
#   'audiCnt': '6475',
#   'audiInten': '5720',
#   'audiChange': '757.6',
#   'audiAcc': '566226',
#   'scrnCnt': '326',
#   'showCnt': '388'},
#  {'rnum': '7',
#   'rank': '7',
#   'rankInten': '-2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20211937',
#   'movieNm': '귀공자',
#   'openDt': '2023-06-21',
#   'salesAmt': '42776700',
#   'salesShare': '0.6',
#   'salesInten': '7136700',
#   'salesChange': '20',
#   'salesAcc': '163858700',
#   'audiCnt': '3546',
#   'audiInten': '-3582',
#   'audiChange': '-50.3',
#   'audiAcc': '26612',
#   'scrnCnt': '16',
#   'showCnt': '16'},
#  {'rnum': '8',
#   'rank': '8',
#   'rankInten': '3',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231839',
#   'movieNm': '인어공주',
#   'openDt': '2023-05-24',
#   'salesAmt': '27035851',
#   'salesShare': '0.4',
#   'salesInten': '17228264',
#   'salesChange': '175.7',
#   'salesAcc': '6593279017',
#   'audiCnt': '2576',
#   'audiInten': '1622',
#   'audiChange': '170',
#   'audiAcc': '640283',
#   'scrnCnt': '103',
#   'showCnt': '123'},
#  {'rnum': '9',
#   'rank': '9',
#   'rankInten': '-2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231677',
#   'movieNm': '남은 인생 10년',
#   'openDt': '2023-05-24',
#   'salesAmt': '21712100',
#   'salesShare': '0.3',
#   'salesInten': '6766500',
#   'salesChange': '45.3',
#   'salesAcc': '1324148100',
#   'audiCnt': '2039',
#   'audiInten': '527',
#   'audiChange': '34.9',
#   'audiAcc': '123350',
#   'scrnCnt': '57',
#   'showCnt': '103'},
#  {'rnum': '10',
#   'rank': '10',
#   'rankInten': '2',
#   'rankOldAndNew': 'OLD',
#   'movieCd': '20231592',
#   'movieNm': '분노의 질주: 라이드 오어 다이',
#   'openDt': '2023-05-17',
#   'salesAmt': '14698775',
#   'salesShare': '0.2',
#   'salesInten': '6243513',
#   'salesChange': '73.8',
#   'salesAcc': '18429259665',
#   'audiCnt': '1424',
#   'audiInten': '563',
#   'audiChange': '65.4',
#   'audiAcc': '1768880',
#   'scrnCnt': '67',
#   'showCnt': '76'}]

# %%
df = DataFrame(dailyBoxOfficeList)
df
# Out:
#   rnum rank rankInten rankOldAndNew   movieCd                    movieNm  \
# 0    1    1         0           OLD  20226411                      범죄도시3
# 1    2    2         0           OLD  20228930                       엘리멘탈
# 2    3    3         0           OLD  20231971                        플래시
# 3    4    4         0           OLD  20232025             트랜스포머: 비스트의 서막
# 4    5    5         1           OLD  20231496      가디언즈 오브 갤럭시: Volume 3
# 5    6    6         7           OLD  20090860  포켓 몬스터 DP: 아르세우스 초극의 시공으로
# 6    7    7        -2           OLD  20211937                        귀공자
# 7    8    8         3           OLD  20231839                       인어공주
# 8    9    9        -2           OLD  20231677                  남은 인생 10년
# 9   10   10         2           OLD  20231592          분노의 질주: 라이드 오어 다이
#
#        openDt    salesAmt salesShare  salesInten salesChange     salesAcc  \
# 0  2023-05-31  2850445922       41.9  1453653836       104.1  85956973037
# 1  2023-06-14  1793175846       26.4  1140734210       174.8   3336652509
# 2  2023-06-14  1412437187       20.8   751869631       113.8   3474133965
# 3  2023-06-06   326281508        4.8   167091544         105   6999262769
# 4  2023-05-03    74488561        1.1    36960326        98.5  44089148518
# 5  2009-12-24    62235941        0.9    55283563       795.2   4349844994
# 6  2023-06-21    42776700        0.6     7136700          20    163858700
# 7  2023-05-24    27035851        0.4    17228264       175.7   6593279017
# 8  2023-05-24    21712100        0.3     6766500        45.3   1324148100
# 9  2023-05-17    14698775        0.2     6243513        73.8  18429259665
#
#   audiCnt audiInten audiChange  audiAcc scrnCnt showCnt
# 0  278729    139733      100.5  8680598    1464    7378
# 1  177851    112850      173.6   336812    1221    4477
# 2  130312     69719      115.1   324602    1239    4645
# 3   32662     16468      101.7   689264     626    1259
# 4    7042      3413         94  4183204     202     253
# 5    6475      5720      757.6   566226     326     388
# 6    3546     -3582      -50.3    26612      16      16
# 7    2576      1622        170   640283     103     123
# 8    2039       527       34.9   123350      57     103
# 9    1424       563       65.4  1768880      67      76

# %%
df.to_excel("박스오피스_순위_%s.xlsx" % yesterday)
